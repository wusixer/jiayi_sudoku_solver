# %%
# %load_ext autoreload
# %autoreload 2

# %%
import jiayi_sudoku_solver.Sudoku as Sudoku 
from jiayi_sudoku_solver.genetic_algo import *
from jiayi_sudoku_solver.util import show_sudoku_with_known_truth
from jiayi_sudoku_solver.simulated_annealing import *

# %%
startingSudoku1 =   """
                    430260700
                    682070493
                    107804500
                    820190047
                    004602910
                    950703028
                    509306070
                    240057106
                    703018250
                    """
solvedstartingSoduku1 = """
                        435269781
                        681572493
                        197834562
                        826195347
                        374682915
                        951743628
                        519326874
                        248957136
                        763418259
                        """

# %%
pred_sudoku1 = simulated_annealing(startingSudoku1, max_iteration = 10000000, temp=10)
# Out:
#   0%|             | 1156/10000000 [00:00<14:25, 11556.21it/s]/Users/jiayicox/Documents/practice/jiayi_sudoku_solver/jiayi_sudoku_solver/simulated_annealing.py:128: RuntimeWarning: overflow encountered in exp
#   metropolis = np.exp(-diff / t*10)
# 100%|█████████| 10000000/10000000 [15:26<00:00, 10796.44it/s]
# max iteration 10000000 has reached,  current_best_err is 2

# %%
show_sudoku_with_known_truth(original_puzzle = Sudoku.Sudoku(startingSudoku1).np_Sudoku,
                             solved = Sudoku.Sudoku(solvedstartingSoduku1).np_Sudoku,
                            pred = pred_sudoku1)

# %%
startingSudoku2 = """
                    000600400
                    700003600
                    000091080
                    000000000
                    050180003
                    000306045
                    040200060
                    903000000
                    020000100
                   """
solvedstartingSoduku2 = """
                        581672439
                        791843651
                        364591782
                        438957216
                        256184973
                        179326845
                        845219367
                        913768524
                        627435198
                        """

# %%
pred_sudoku2 = simulated_annealing(startingSudoku2, max_iteration = 20000000, temp=10)
# Out:
# 100%|██████████| 20000000/20000000 [36:20<00:00, 9170.78it/s]
# max iteration 20000000 has reached,  current_best_err is 20

# %%
show_sudoku_with_known_truth(original_puzzle = Sudoku.Sudoku(startingSudoku2).np_Sudoku,
                             solved = Sudoku.Sudoku(solvedstartingSoduku2).np_Sudoku,
                            pred = pred_sudoku2)

# %%
startingSudoku3 = """
                    020608000
                    580009700
                    000040000
                    370000500
                    600000004
                    008000013
                    000020000
                    009800036
                    000306090
                  """
solvedstartingSoduku3 = """
                        123678945
                        584239761
                        967145328
                        372461589
                        691583274
                        458792613
                        836924157
                        219857436
                        745316892
                        """

# %%
pred_sudoku3 = simulated_annealing(startingSudoku3, max_iteration = 40000000, temp=10)
# Out:
# 100%|█████████| 40000000/40000000 [54:59<00:00, 12124.61it/s]
# max iteration 40000000 has reached,  current_best_err is 23

# %%
show_sudoku_with_known_truth(original_puzzle = Sudoku.Sudoku(startingSudoku3).np_Sudoku,
                             solved = Sudoku.Sudoku(solvedstartingSoduku3).np_Sudoku,
                            pred = pred_sudoku3)
